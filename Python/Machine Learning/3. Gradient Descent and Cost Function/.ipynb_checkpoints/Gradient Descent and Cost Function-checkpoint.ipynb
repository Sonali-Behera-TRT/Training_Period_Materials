# %% [markdown]
# # Question 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])

# %%
def gradient_descent(x, y):
    learning_rate = 0.08
    iterations = 10000
    m_curr = 0
    b_curr = 0
    n = len(x)
    for i in range(iterations):
        y_pred = m_curr * x + b_curr
        cost = (1 / n) * sum([j**2 for j in y - y_pred])
        plt.plot(x, y_pred, color='green')
        md = -(2 / n) * sum(x * (y - y_pred))
        bd = -(2 / n) * sum(y - y_pred)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        # print(f'm {m_curr}, b {b_curr}, cost {cost}, iteration {i}')

# %%
gradient_descent(x, y)

# %% [markdown]
# # Question 2

# %%
import math

x = np.array([98, 68, 81, 80, 83, 52, 66, 30, 68, 73])
y = np.array([92, 56, 88, 70, 80, 49, 65, 35, 66, 67])

# %%
def gradient_descent(x, y):
    m_curr = 0
    c_curr = 0
    learning_rate = 0.002
    iteration = 100
    n = len(x)
    prev_cost = 0
    for i in range(iteration):
        y_pred = m_curr * x + c_curr
        cost = (1 / n) * sum([j**2 for j in (y - y_pred)])
        md = -(2 / n) * sum(x * (y - y_pred))
        cd = -(2 / n) * sum(y - y_pred)
        m_curr = m_curr - learning_rate * md
        c_curr = c_curr - learning_rate * cd
        
        if(math.isclose(cost, prev_cost, rel_tol = 1e-20)):
            break
        prev_cost = cost
        #print(f'm:{m_curr}, c:{c_curr}, cost:{cost}, iteration:{i}')
        print(f'prev: {prev_cost}, curr: {cost}')
        
    return m_curr, c_curr

# %%
m, c = gradient_descent(x, y)
print(m, c)
# Out:
# m:19.783600000000003, c:0.2672, cost:4734.0, iteration:0
# m:-371.9351681600001, c:-4.998163360000002, cost:1844622.0255149924, iteration:1
# m:7384.158449438083, c:99.28210231097603, cost:723165920.4577887, iteration:2
# m:-146187.7300042622, c:-1965.4585285611565, cost:283514514170.7089, iteration:3
# m:2894560.1040609623, c:38916.7598147448, cost:111150817086440.84, iteration:4
# m:-57312730.98647664, c:-770557.6451199593, cost:4.357626690251232e+16, iteration:5
# m:1134801215.4018614, c:15257164.43647939, cost:1.708391433310594e+19, iteration:6
# m:-22469244663.97425, c:-302094283.780427, cost:6.697685453273095e+21, iteration:7
# m:444894620647.4286, c:5981514901.669096, cost:2.6258028199109134e+24, iteration:8
# m:-8808984299731.48, c:-118434947090.69144, cost:1.0294362876779567e+27, iteration:9
# m:174419291202430.66, c:2345030802902.8604, cost:4.0358669065033876e+29, iteration:10
# m:-3453529726972270.5, c:-46431983140508.09, cost:1.5822466996718823e+32, iteration:11
# m:6.8380438269519976e+16, c:919360656453501.0, cost:6.20313968874549e+34, iteration:12
# m:-1.3539435613982702e+18, c:-1.82034873263301e+16, cost:2.4319179813153686e+37, iteration:13
# m:2.680829801392116e+19, c:3.6043194638993146e+17, cost:9.534244535191343e+39, iteration:14
# m:-1.0756252825525989e+57, c:-1.4461556417170973e+55, cost:1.5348636635790304e+115, iteration:43
# m:2.129755179469851e+58, c:2.863411188102044e+56, cost:6.017376247543948e+117, iteration:44
# m:-4.216949153253889e+59, c:-5.669599727462742e+57, cost:2.3590901109792074e+120, iteration:45
# m:8.349626441831326e+60, c:1.1225897699642587e+59, cost:9.248725562061078e+122, iteration:46
# m:-1.653239325030379e+62, c:-2.222745612047599e+60, cost:3.625928663098699e+125, iteration:47
# m:3.273440177076268e+63, c:4.4010716898249993e+61, cost:1.421531926929707e+128, iteration:48
# m:-6.481463651791741e+64, c:-8.714191994798676e+62, cost:5.573063364003313e+130, iteration:49
# m:1.2833401191714747e+66, c:1.7254238847727766e+64, cost:2.1848988876583813e+133, iteration:50
# m:-2.5410338620348012e+67, c:-3.416366754280075e+65, cost:8.565815311063797e+135, iteration:51
# m:5.031287490783072e+68, c:6.76446054952301e+66, cost:3.35819622398596e+138, iteration:52
# m:-9.962029311423446e+69, c:-1.3393739553496975e+68, cost:1.3165684140104345e+141, iteration:53
# m:1.9724976595645468e+71, c:2.6519817495211662e+69, cost:5.16155779221434e+143, iteration:54
# m:-3.905576760877526e+72, c:-5.250966073890166e+70, cost:2.0235696496177233e+146, iteration:55
# m:7.733104149017846e+73, c:1.03969964024541e+72, cost:7.933329997836346e+148, iteration:56
# m:-1.5311669297755812e+75, c:-2.0586218358969474e+73, cost:3.1102326952996035e+151, iteration:57
# m:3.0317348915262486e+76, c:4.0761040007971906e+74, cost:1.2193552293360913e+154, iteration:58
# m:-6.002883339339647e+77, c:-8.07075079822799e+75, cost:4.7804370957718585e+156, iteration:59
# m:1.1885804555813528e+79, c:1.5980215037290145e+77, cost:1.874152689620593e+159, iteration:60
# m:-2.3534082198995112e+80, c:-3.164108012034052e+78, cost:7.347546330269148e+161, iteration:61
# m:4.659785733042035e+81, c:6.264984224840443e+79, cost:2.8805783741334684e+164, iteration:62
# m:-9.2264499181486e+82, c:-1.2404768480791421e+81, cost:1.1293201017789943e+167, iteration:63
# m:1.826851768923093e+84, c:2.4561639030456666e+82, cost:4.427457706877255e+169, iteration:64
# m:-3.617195579258204e+85, c:-4.86324362116562e+83, cost:1.7357684252062432e+172, iteration:65
# m:7.162104819439189e+86, c:9.629299774937843e+84, cost:6.805015937843921e+174, iteration:66
# m:-1.418108153697167e+88, c:-1.9066166817568164e+86, cost:2.6678813395748595e+177, iteration:67
# m:2.8078767154092783e+89, c:3.7751313762343004e+87, cost:1.045933015743511e+180, iteration:68
# m:-5.559640587625618e+90, c:-7.474820211211408e+88, cost:4.100541718983069e+182, iteration:69
# m:1.1008176852618234e+92, c:1.4800262989964571e+90, cost:1.6076022207949834e+185, iteration:70
# m:-2.1796365378049156e+93, c:-2.930475628612011e+91, cost:6.302545071888426e+187, iteration:71
# m:4.315715036685884e+94, c:5.802388387092788e+92, cost:2.4708894942644412e+190, iteration:72
# m:-8.545184463017874e+95, c:-1.1488821359219293e+94, cost:9.687030910890514e+192, iteration:73
# m:1.6919601244820747e+97, c:2.2748049151219737e+95, cost:3.7977646546464857e+195, iteration:74
# m:-3.350107976283964e+98, c:-4.504149938505732e+96, cost:1.4888995921203547e+198, iteration:75
# m:6.633267114493593e+99, c:8.918288567814794e+97, cost:5.837175804730089e+200, iteration:76
# m:-1.313397446401966e+101, c:-1.7658353310769734e+99, cost:2.2884431935939498e+203, iteration:77
# m:2.6005478483537577e+102, c:3.496382061164631e+100, cost:8.971756934342731e+205, iteration:78
# m:-5.149126130939335e+103, c:-6.92289213070511e+101, cost:3.5173441365837566e+208, iteration:79
# m:1.0195351694492489e+105, c:1.3707436605888153e+103, cost:1.3789617647578944e+211, iteration:80
# m:-2.018695862776012e+106, c:-2.7140942651854543e+104, cost:5.406168617072211e+213, iteration:81
# m:3.9970499385424506e+107, c:5.373949843509259e+105, cost:2.1194684191514068e+216, iteration:82
# m:-7.914222496712422e+108, c:-1.064050622375117e+107, cost:8.309297578315173e+218, iteration:83
# m:1.5670286508931945e+110, c:2.106837168092232e+108, cost:3.257629395234793e+221, iteration:84
# m:-3.1027416701264026e+111, c:-4.171571125955386e+109, cost:1.2771415606046417e+224, iteration:85
# m:6.143477891135848e+112, c:8.259777225528265e+110, cost:5.006986271089007e+226, iteration:86
# m:-1.216418400612043e+114, c:-1.6354490371953217e+112, cost:1.9629704562276432e+229, iteration:87
# m:2.408527794138425e+115, c:3.238215124006617e+113, cost:7.695753100566202e+231, iteration:88
# m:-4.768923367336864e+116, c:-6.411717486059978e+114, cost:3.017091551071523e+234, iteration:89
# m:9.442544171123853e+117, c:1.2695302673462297e+116, cost:1.182839588094041e+237, iteration:90
# m:-1.8696387749551124e+119, c:-2.5136901356185448e+117, cost:4.637278874303915e+239, iteration:91
# m:3.7019145322140577e+120, c:4.977146477266886e+118, cost:1.8180280381650266e+242, iteration:92
# m:-7.329849694707283e+121, c:-9.854829242934723e+119, cost:7.127511709224759e+244, iteration:93
# m:1.451321905988665e+123, c:1.9512718753805263e+121, cost:2.7943146144440654e+247, iteration:94
# m:-2.8736404735877574e+124, c:-3.863549370356407e+122, cost:1.0955007137189196e+250, iteration:95
# m:5.689853875537219e+125, c:7.649889246863871e+123, cost:4.294870046325938e+252, iteration:96
# m:-1.1266001235201924e+127, c:-1.5146902467014424e+125, cost:1.6837879230775704e+255, iteration:97
# m:2.2306861759184913e+128, c:2.999110796790994e+126, cost:6.601228301022078e+257, iteration:98
# m:-4.416794132674064e+129, c:-5.938287112507719e+127, cost:2.587987149983099e+260, iteration:99
# -4.416794132674064e+129 -5.938287112507719e+127
