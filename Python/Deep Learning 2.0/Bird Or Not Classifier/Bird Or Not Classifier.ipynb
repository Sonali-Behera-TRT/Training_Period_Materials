# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------
# aiofiles                 23.1.0
# aiohttp                  3.8.4
# aiosignal                1.3.1
# altair                   5.0.1
# anyio                    3.6.2
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asttokens                2.2.1
# astunparse               1.6.3
# async-timeout            4.0.2
# attrs                    23.1.0
# backcall                 0.2.0
# beautifulsoup4           4.12.2
# bleach                   6.0.0
# blinker                  1.6.2
# blis                     0.7.9
# catalogue                2.0.8
# certifi                  2023.5.7
# cffi                     1.15.1
# charset-normalizer       3.1.0
# click                    8.1.3
# colorama                 0.4.6
# comm                     0.1.3
# confection               0.0.4
# contourpy                1.0.7
# cycler                   0.11.0
# ...

# %%
from fastbook import *
